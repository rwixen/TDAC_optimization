# %%
import numpy as np
from TDAC_opt import min_stopband_energy_TDAC_window, plot_filter_and_frequency_response

# %%
M = 8 # number of frequency channels
m = 2 # extension factor such that the length of the filter is 2 * m * M
p0, betas = min_stopband_energy_TDAC_window(m, M)
plot_filter_and_frequency_response(p0, m, M)
